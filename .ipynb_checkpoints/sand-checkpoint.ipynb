# %%
from tqdm import tqdm
import torch 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
import torch
import torchaudio.functional as TAF

import numpy as np
from sklearn.cross_decomposition import CCA

try:
    import pymp
    pymp_available = True
except ImportError:
    pymp_available = False
    print("Please install the pymp library using `pip install pymp` to speed up non-batched metrics")

def hsic_biased(K, L):
    """ Compute the biased HSIC (the original CKA) """
    H = torch.eye(K.shape[0], dtype=K.dtype, device=K.device) - 1 / K.shape[0]
    return torch.trace(K @ H @ L @ H)

def similarity(K, L, topk, n, device='cuda' if torch.cuda.is_available() else 'cpu'):                         
        K_hat, L_hat = K, L
        # get topk indices for each row
        _, topk_K_indices = torch.topk(K_hat, topk, dim=1)
        _, topk_L_indices = torch.topk(L_hat, topk, dim=1)
        # create masks for nearest neighbors
        mask_K = torch.zeros(n, n, device=device).scatter_(1, topk_K_indices, 1)
        mask_L = torch.zeros(n, n, device=device).scatter_(1, topk_L_indices, 1)
        # intersection of nearest neighbors
        mask = mask_K * mask_L
        sim = hsic_biased(mask * K, mask * L)
        return sim

def cknna(feats_A, feats_B, topk=None, device='cuda' if torch.cuda.is_available() else 'cpu'):
    """ similarity only cka variant """
    n = feats_A.shape[0]
            
    if topk < 2:
        raise ValueError("CKNNA requires topk >= 2")
    
    if topk is None:
        topk = feats_A.shape[0] - 1
                        
    K = feats_A @ feats_A.T
    L = feats_B @ feats_B.T
    
    device = K.device
    sim_kl = similarity(K, L, topk, n, device)
    sim_kk = similarity(K, K, topk, n, device)
    sim_ll = similarity(L, L, topk, n, device)

    return sim_kl.item() / (torch.sqrt(sim_kk * sim_ll) + 1e-6).item()

def linear_local_CKNNA(source_base, target_base, source_query, target_query, device):
    #cka = LinearCKA(target_base.shape[0]+1, device)
    graph = []
    for source_ind in tqdm(range(source_query.shape[0])):
        source = source_query[source_ind:source_ind+1, :]
        row = []
        for target_ind in range(target_query.shape[0]):
            target = target_query[target_ind:target_ind+1, :]
    
            row.append(cknna(
                torch.cat((source_base, source), axis = 0), 
                torch.cat((target_base, target), axis = 0),
                N_base=source_base.shape[0],
                topk=5,
                ))
        graph.append(row)
    return torch.tensor(graph)

# %%
def vectorized_linear_cka_graph(
        base_source: torch.Tensor,   
        base_target: torch.Tensor,   
        query_source: torch.Tensor,   
        query_target: torch.Tensor,   
    ) -> torch.Tensor:                


        B  = base_source.shape[0]
        N  = query_target.shape[0]
        M  = query_source.shape[0]
        n  = B + 1

        device = "cuda" if torch.cuda.is_available() else "cpu"

        K_bb = base_source @ base_source.T
        L_bb = base_target @ base_target.T

        K_bq = base_source @ query_source.T   
        L_bq = base_target @ query_target.T   

        K_qq = (query_source * query_source).sum(dim=1)   
        L_qq = (query_target * query_target).sum(dim=1)   

        K_bb_rowsum = K_bb.sum(dim=1)
        K_bb_total  = K_bb_rowsum.sum()
        L_bb_rowsum = L_bb.sum(dim=1)
        L_bb_total  = L_bb_rowsum.sum()

        KL_bb = (K_bb * L_bb).sum()
        KK_bb = (K_bb * K_bb).sum()
        LL_bb = (L_bb * L_bb).sum()

        graph      = torch.zeros((N, M), device=device)
        batch_size = 1

        for i_start in tqdm(range(0, N, batch_size), desc="[CKAMethod] CKA batches"):

            i_end = min(i_start + batch_size, N)
            bs    = i_end - i_start

            l_bi = L_bq[:, i_start:i_end]
            l_ii = L_qq[i_start:i_end]

            L_rowsum_base = L_bb_rowsum.unsqueeze(1) + l_bi
            L_rowsum_last = l_bi.sum(0) + l_ii
            L_total       = L_bb_total + 2 * l_bi.sum(0) + l_ii

            LL_bq  = torch.einsum('bn,bn->n', l_bi, l_bi)
            LL_qq  = l_ii ** 2
            LL_sum = LL_bb + 2 * LL_bq + LL_qq
            LL_rs  = (L_rowsum_base ** 2).sum(0) + L_rowsum_last ** 2
            var_L  = LL_sum - (2.0/n)*LL_rs + (1.0/n**2)*(L_total**2)

            for j_start in range(0, M, batch_size):

                j_end = min(j_start + batch_size, M)
                ms    = j_end - j_start

                k_bj = K_bq[:, j_start:j_end]
                k_jj = K_qq[j_start:j_end]

                K_rowsum_base = K_bb_rowsum.unsqueeze(1) + k_bj
                K_rowsum_last = k_bj.sum(0) + k_jj
                K_total       = K_bb_total + 2 * k_bj.sum(0) + k_jj

                KL_bq    = torch.einsum('bm,bn->mn', k_bj, l_bi)
                KL_qq    = k_jj.unsqueeze(1) * l_ii.unsqueeze(0)
                KL_sum   = KL_bb + 2 * KL_bq + KL_qq

                RS_base  = torch.einsum('bm,bn->mn', K_rowsum_base, L_rowsum_base)
                RS_last  = K_rowsum_last.unsqueeze(1) * L_rowsum_last.unsqueeze(0)
                RS       = RS_base + RS_last

                KL_total = K_total.unsqueeze(1) * L_total.unsqueeze(0)
                hsic     = KL_sum - (2.0/n)*RS + (1.0/n**2)*KL_total

                KK_bq  = torch.einsum('bm,bm->m', k_bj, k_bj)
                KK_qq  = k_jj ** 2
                KK_sum = KK_bb + 2 * KK_bq + KK_qq
                KK_rs  = (K_rowsum_base ** 2).sum(0) + K_rowsum_last ** 2
                var_K  = KK_sum - (2.0/n)*KK_rs + (1.0/n**2)*(K_total**2)

                denom  = torch.sqrt(var_K.unsqueeze(1) * var_L.unsqueeze(0)) + 1e-8
                scores = (hsic / denom).T

                graph[i_start:i_end, j_start:j_end] = scores

        return graph

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans
import torch
from tqdm import tqdm


def centering(K, device):
    n = K.shape[0]
    unit = torch.ones(n, n).to(device)
    I = torch.eye(n).to(device)
    H = I - unit / n

    return torch.matmul(torch.matmul(H, K), H)

def linear_HSIC(X, Y, device):
    L_X = torch.matmul(X, X.T)
    L_Y = torch.matmul(Y, Y.T)
    return torch.sum(centering(L_X, device) * centering(L_Y, device))

def linear_CKA(X, Y, device):
    hsic = linear_HSIC(X, Y, device)
    var1 = torch.sqrt(linear_HSIC(X, X, device))
    var2 = torch.sqrt(linear_HSIC(Y, Y, device))

    return hsic / (var1 * var2)

def centered_scaled_corr(X, device):
    L_X = torch.matmul(X, X.T)
    var1 = torch.sqrt(linear_HSIC(X, X, device))
    C = centering(L_X, device)
    C = C / (var1)
    return C    


class LinearCKA:
    def __init__(self, n, device):
        self.H = self.get_centering_matrix(n, device)

    def linear_HSIC(self, X, Y, sigma=None):
        L_X = torch.matmul(X, X.T)
        L_Y = torch.matmul(Y, Y.T)
        return torch.sum(self.centering(L_X)*self.centering(L_Y))
    
    def centering(self, K):
        return torch.matmul(torch.matmul(self.H, K), self.H)
    
    def get_centering_matrix(self, n, device):
        unit = torch.ones(n, n).to(device)
        I = torch.eye(n).to(device)
        H = I - unit / n
        return H

    def calculate(self, X, Y, sigma=None):
        hsic = self.linear_HSIC(X, Y, sigma)
        # print(hsic)
        # asd
        var1 = torch.sqrt(self.linear_HSIC(X, X, sigma))
        var2 = torch.sqrt(self.linear_HSIC(Y, Y, sigma))

        return hsic / (var1 * var2)


def linear_local_CKNNA(source_base, target_base, source_query, target_query, device):
    #cka = LinearCKA(target_base.shape[0]+1, device)
    graph = []
    for source_ind in tqdm(range(source_query.shape[0])):
        source = source_query[source_ind:source_ind+1, :]
        row = []
        for target_ind in range(target_query.shape[0]):
            target = target_query[target_ind:target_ind+1, :]
    
            row.append(cknna(
                torch.cat((source_base, source), axis = 0), 
                torch.cat((target_base, target), axis = 0),
                N_base=source_base.shape[0],
                topk=5,
                ))
        graph.append(row)
    return torch.tensor(graph)

# %%
def vectorized_cknna_graph(
        base_source:  torch.Tensor,   # (B, d)
        base_target:  torch.Tensor,   # (B, d)
        query_source: torch.Tensor,   # (M, d)
        query_target: torch.Tensor,   # (N, d)
        topk:               int  = 7,
        distance_agnostic:  bool = False,
        unbiased:           bool = True,
        batch_size:         int  = 1,
    ) -> torch.Tensor:                # (N, M)  — same axis convention as vectorized_linear_cka_graph

        B = base_source.shape[0]
        N = query_target.shape[0]
        M = query_source.shape[0]
        n = B + 1                     # augmented neighbourhood size
        device = base_source.device

        if topk < 2:
            raise ValueError("CKNNA requires topk >= 2")
        if topk >= n:
            raise ValueError(f"topk ({topk}) must be < n=B+1 ({n})")
        if unbiased and n <= 3:
            raise ValueError("Unbiased HSIC requires n > 3  (i.e. B >= 3)")

        # ------------------------------------------------------------------ #
        #  Pre-compute base-base and cross kernels  (shared across all pairs) #
        # ------------------------------------------------------------------ #
        K_bb = base_source @ base_source.T          # (B, B)
        L_bb = base_target @ base_target.T          # (B, B)
        K_bq = base_source @ query_source.T         # (B, M)
        L_bq = base_target @ query_target.T         # (B, N)
        K_qq = (query_source * query_source).sum(1) # (M,)
        L_qq = (query_target * query_target).sum(1) # (N,)

        # ------------------------------------------------------------------ #
        #  Helpers                                                            #
        # ------------------------------------------------------------------ #

        def build_kernel_batch(k_bb, k_bq_batch, k_qq_batch):
            """
            Assemble augmented kernel matrices for a batch of query points.

            Layout – query point is prepended at index 0:
                [ k_qq      k_bq^T ]
                [ k_bq      K_bb   ]

            Returns shape (bs, n, n).
            """
            bs = k_bq_batch.shape[1]               # k_bq_batch: (B, bs)
            K  = torch.empty(bs, n, n, device=device)
            K[:, 0, 0]   = k_qq_batch             # scalar diagonal per query
            K[:, 0, 1:]  = k_bq_batch.T           # (bs, B)  — query-to-base row
            K[:, 1:, 0]  = k_bq_batch.T           # (bs, B)  — base-to-query col
            K[:, 1:, 1:] = k_bb                   # (B, B)   — broadcast (no copy)
            return K

        def topk_mask(K_full):
            """
            Binary (0/1) nearest-neighbour mask.
            When unbiased the diagonal is excluded from candidate neighbours.

            K_full : (bs, n, n)
            returns : (bs, n, n)
            """
            K_hat = K_full.clone()
            if True:
                # exclude self from neighbourhood
                diag_idx = torch.arange(n, device=device)
                K_hat[:, diag_idx, diag_idx] = float('-inf')

            _, idx  = torch.topk(K_hat, topk, dim=2)          # (bs, n, topk)
            mask    = torch.zeros(K_full.shape, device=device)
            mask.scatter_(2, idx, 1.0)
            return mask                                        # (bs, n, n)

        def hsic_biased(K, L):
            """
            Biased HSIC via explicit centering  ⟨HKH, L⟩_F.
            K, L : (..., n, n)
            returns : (...)
            """
            row = K.sum(dim=-1, keepdim=True) / n           # (..., n, 1)
            col = K.sum(dim=-2, keepdim=True) / n           # (..., 1, n)
            tot = K.sum(dim=(-2, -1), keepdim=True) / n**2  # (..., 1, 1)
            HKH = K - row - col + tot
            return (HKH * L).sum(dim=(-2, -1))


        def hsic_unbiased(K, L):
            """
            Unbiased HSIC estimator (Song et al., 2012).
            Diagonal of K and L must be 0 — guaranteed when unbiased=True because
            the mask never assigns 1 on the diagonal.

            K, L : (..., n, n)
            returns : (...)
            """
            tr_KL  = (K * L).sum(dim=(-2, -1))
            sum_K  = K.sum(dim=(-2, -1))
            sum_L  = L.sum(dim=(-2, -1))
            # 1^T (KL) 1  — sum of all entries of the matrix product
            one_KL = (K @ L).sum(dim=(-2, -1))

            return (
                tr_KL
                + sum_K * sum_L / ((n - 1) * (n - 2))
                - 2.0 * one_KL / (n - 2)
            ) / (n * (n - 3))

        hsic = hsic_unbiased

        # ------------------------------------------------------------------ #
        #  Main double-batch loop                                             #
        # ------------------------------------------------------------------ #
        graph = torch.zeros(N, M, device=device)

        for j_start in tqdm(range(0, M, batch_size), desc="[CKNNA] source batches"):
            j_end  = min(j_start + batch_size, M)

            K_full = build_kernel_batch(K_bb, K_bq[:, j_start:j_end], K_qq[j_start:j_end])
            mK     = topk_mask(K_full)             # (bs_j, n, n)

            # Denominator term for source:  similarity(K, K, topk)
            #   mask = mK ∩ mK = mK   (binary mask intersected with itself)
            if distance_agnostic:
                sim_kk = mK.sum(dim=(-2, -1))                # (bs_j,)
            else:
                mKK    = mK * K_full                         # (bs_j, n, n)
                sim_kk = hsic(mKK, mKK)                      # (bs_j,)

            for i_start in range(0, N, batch_size):
                i_end  = min(i_start + batch_size, N)

                L_full = build_kernel_batch(L_bb, L_bq[:, i_start:i_end], L_qq[i_start:i_end])
                mL     = topk_mask(L_full)         # (bs_i, n, n)

                # NN intersection mask for every (j, i) pair
                # Shape: (bs_j, 1, n, n) * (1, bs_i, n, n) → (bs_j, bs_i, n, n)
                mask = mK.unsqueeze(1) * mL.unsqueeze(0)

                # ---- cross similarity  sim_kl[j, i] ---------------------------
                if distance_agnostic:
                    # Normalised count of shared nearest neighbours
                    sim_kl = mask.sum(dim=(-2, -1))          # (bs_j, bs_i)
                else:
                    # Apply intersection mask to each kernel separately
                    mKL_K  = mask * K_full.unsqueeze(1)      # (bs_j, bs_i, n, n)
                    mKL_L  = mask * L_full.unsqueeze(0)      # (bs_j, bs_i, n, n)
                    sim_kl = hsic(mKL_K, mKL_L)             # (bs_j, bs_i)

                # ---- target self-similarity  sim_ll[i] ------------------------
                if distance_agnostic:
                    sim_ll = mL.sum(dim=(-2, -1))            # (bs_i,)
                else:
                    mLL    = mL * L_full                     # (bs_i, n, n)
                    sim_ll = hsic(mLL, mLL)                  # (bs_i,)

                # ---- normalise -------------------------------------------------
                denom  = torch.sqrt(sim_kk.unsqueeze(1) * sim_ll.unsqueeze(0)) + 1e-6
                scores = sim_kl / denom                      # (bs_j, bs_i)

                graph[i_start:i_end, j_start:j_end] = scores.T

            return graph   # (N, M)

# %%
train_idx = torch.randperm(100)
source_base = torch.cat([torch.randn(50, 512), 5*torch.randn(50, 512) - 2], dim=0)[train_idx]
target_base = torch.cat([torch.randn(50, 512), 5*torch.randn(50, 512) - 2], dim=0)[train_idx]
val_idx1 = torch.randperm(30)
val_idx2 = torch.randperm(30)

source_query = torch.cat([torch.randn(15, 512), 5*torch.randn(15, 512) - 2], dim=0)[val_idx1]
target_query = torch.cat([torch.randn(15, 512), 5*torch.randn(15, 512) - 2], dim=0)[val_idx2]
device = "cuda" if torch.cuda.is_available() else "cpu"
graph1 = linear_local_CKA(source_base, target_base, source_query, target_query, device)
graph2 = vectorized_linear_cka_graph(source_base, target_base, source_query, target_query)
graph3 = vectorized_cknna_graph(source_base, target_base, source_query, target_query, topk=5)
# Out:
# ...
# [CKNNA] source batches:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
# Plot the heatmap
sns.heatmap(graph1.T, cmap='viridis')
plt.show()

# %%
# Plot the heatmap
sns.heatmap(graph2, cmap='viridis')
plt.show()

# %%
# Plot the heatmap
val_idx1
diff_graph = graph2[val_idx1, val_idx2] - graph1.T[val_idx1, val_idx2]
# diff_graph[val_idx1, val_idx2] = 0
# sns.heatmap(diff_graph, cmap='viridis')
# plt.show()

# %%
diff_graph

# %%
# # Plot the heatmap
# sns.heatmap(graph3.T, cmap='viridis')
# plt.show()

# %%
sales = 120*np.random.rand(100)
shark_attack = 0.2*sales - 10*np.random.normal(0, 0.2, 100)  # Add some noise
mask_shark_attack = shark_attack > 0
mask_sales = sales > 0
mask = mask_shark_attack & mask_sales
sales = sales[mask]
shark_attack = shark_attack[mask]

# %%
plt.rcParams.update({
    'figure.figsize': (14, 6),
    'figure.dpi': 150,
    'font.family': 'sans-serif',
    'font.size': 11,
    'axes.spines.top': False,
    'axes.spines.right': False,
    'axes.grid': True,
    'grid.alpha': 0.3,
    'grid.linewidth': 0.5,
})
plt.figure(figsize=(10, 6))
plt.scatter(sales, shark_attack, color='blue', alpha=0.6, edgecolors='w', s=100,)
plt.xlabel('Ice Cream Sales (in thousands)')
plt.ylabel('Shark Attacks (per month)')
plt.legend()
# Out:
# /tmp/ipykernel_1952387/378100178.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    "dinov2_dinov2-giant_gtr_t5_gtr-t5-base": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.0029331377908139457
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.005666666666666667
        }
    },
    "dinov2_dinov2-base_gtr_t5_gtr-t5-base": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.01826544897006866
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.0338
        }
    },
    "dinov2_dinov2-small_gtr_t5_gtr-t5-base": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.01459902673155123
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.020933333333333335
        }
    },
    "dinov2_dinov2-large_gtr_t5_gtr-t5-base": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.013799080061329246
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.0248
        }
    },
    "dinov2_dinov2-giant_gtr_t5_gtr-t5-large": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.0019332044530364642
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.0056
        }
    },
    "dinov2_dinov2-base_gtr_t5_gtr-t5-large": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.02219852009866009
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.028666666666666667
        }
    },
    "dinov2_dinov2-small_gtr_t5_gtr-t5-large": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.015265648956736218
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.0194
        }
    },
    "dinov2_dinov2-large_gtr_t5_gtr-t5-large": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.012999133391107259
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.022133333333333335
        }
    },
    "dinov2_dinov2-giant_gtr_t5_gtr-t5-xl": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.003133124458369442
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.006266666666666667
        }
    },
    "dinov2_dinov2-base_gtr_t5_gtr-t5-xl": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.029464702353176456
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.0406
        }
    },
    "dinov2_dinov2-small_gtr_t5_gtr-t5-xl": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.01959869342043864
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.026866666666666667
        }
    },
    "dinov2_dinov2-large_gtr_t5_gtr-t5-xl": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.022398506766215586
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.0284
        }
    },
    "dinov2_dinov2-giant_gtr_t5_gtr-t5-xxl": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.0041330577961469234
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.005933333333333333
        }
    },
    "dinov2_dinov2-base_gtr_t5_gtr-t5-xxl": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.032197853476434904
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.04066666666666666
        }
    },
    "dinov2_dinov2-small_gtr_t5_gtr-t5-xxl": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.023465102326511566
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.026933333333333333
        }
    },
    "dinov2_dinov2-large_gtr_t5_gtr-t5-xxl": {
        "imagenet1k-classification-Classification-cka": {
            "accuracy": 0.02059862675821612
        },
        "places365-classification-Classification-cka": {
            "accuracy": 0.030466666666666666
        }
    }
}

rows = []
for key, datasets in data.items():
    # Extract language model and vision model
    parts = key.split('_gtr_t5_')
    vision_model = parts[0].replace('dinov2_', '')
    language_model = parts[1]
    
    for dataset, metrics in datasets.items():
        ds_name = 'ImageNet-1k' if 'imagenet1k' in dataset else 'Places365'
        rows.append({
            'Vision Model': vision_model,
            'Language Model': language_model,
            'Dataset': ds_name,
            'Accuracy': metrics['accuracy']
        })

df = pd.DataFrame(rows)

# Sort models to keep the bars ordered logically
vision_order = ['dinov2-small', 'dinov2-base', 'dinov2-large', 'dinov2-giant']
lm_order = ['gtr-t5-base', 'gtr-t5-large', 'gtr-t5-xl', 'gtr-t5-xxl']

# Plot
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(1, 1, figsize=(10, 6))
plt.ylim(0, 0.5)  # Sets min to 0 and max to 100
# Dataset 1: ImageNet-1k
sns.barplot(
    data=df[df['Dataset'] == 'ImageNet-1k'], 
    x='Language Model', 
    y='Accuracy', 
    hue='Vision Model',
    hue_order=vision_order,
    order=lm_order,
    ax=axes
)
axes.set_title('CKA Accuracy on ImageNet-1k')
axes.set_ylabel('Accuracy')
axes.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig('cka_plot.png', dpi=300)
print("Plot saved as cka_plot.png")
# Dataset 2: Places365
# sns.barplot(
#     data=df[df['Dataset'] == 'Places365'], 
#     x='Language Model', 
#     y='Accuracy', 
#     hue='Vision Model',
#     hue_order=vision_order,
#     order=lm_order,
#     ax=axes[1]
# )
# axes[1].set_title('CKA Accuracy on Places365')
# axes[1].set_ylabel('Accuracy')
# axes[1].tick_params(axis='x', rotation=45)
# plt.ylim(0, 0.5)  # Sets min to 0 and max to 100
# plt.tight_layout()
# plt.savefig('cka_plot.png', dpi=300)
# print("Plot saved as cka_plot.png")
# Out:
# Plot saved as cka_plot.png

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



rows = []
for key, datasets in data.items():
    # Extract language model and vision model
    parts = key.split('_gtr_t5_')
    vision_model = parts[0].replace('dinov2_', '')
    language_model = parts[1]
    
    for dataset, metrics in datasets.items():
        ds_name = 'ImageNet-1k' if 'imagenet1k' in dataset else 'Places365'
        rows.append({
            'Vision Model': vision_model,
            'Language Model': language_model,
            'Dataset': ds_name,
            'Accuracy': metrics['accuracy']
        })

df = pd.DataFrame(rows)

# Sort models to keep the bars ordered logically
vision_order = ['dinov2-small', 'dinov2-base', 'dinov2-large', 'dinov2-giant']
lm_order = ['gtr-t5-base', 'gtr-t5-large', 'gtr-t5-xl', 'gtr-t5-xxl']

# Plot
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(1, 1, figsize=(10, 6))
plt.ylim(0, 0.5)  # Sets min to 0 and max to 100
# Dataset 1: ImageNet-1k
sns.barplot(
    data=df[df['Dataset'] == 'Places365'], 
    x='Language Model', 
    y='Accuracy', 
    hue='Vision Model',
    hue_order=vision_order,
    order=lm_order,
    ax=axes
)
axes.set_title('CKA Accuracy on Places365')
axes.set_ylabel('Accuracy')
axes.tick_params(axis='x', rotation=45)
plt.tight_layout()
plt.savefig('cka_plot.png', dpi=300)
print("Plot saved as cka_plot.png")
# Dataset 2: Places365
# sns.barplot(
#     data=df[df['Dataset'] == 'Places365'], 
#     x='Language Model', 
#     y='Accuracy', 
#     hue='Vision Model',
#     hue_order=vision_order,
#     order=lm_order,
#     ax=axes[1]
# )
# axes[1].set_title('CKA Accuracy on Places365')
# axes[1].set_ylabel('Accuracy')
# axes[1].tick_params(axis='x', rotation=45)
# plt.ylim(0, 0.5)  # Sets min to 0 and max to 100
# plt.tight_layout()
# plt.savefig('cka_plot.png', dpi=300)
# print("Plot saved as cka_plot.png")
# Out:
# Plot saved as cka_plot.png

# %%
from datasets import load_dataset
ds = load_dataset("lmms-lab/NoCaps", split="validation", cache_dir="/home/rida.lefdali/work/dataset/nocaps")

# %%
from datasets import Dataset
import polars as pl
from PIL import Image
import io
def load_image(img_struct):
    return Image.open(io.BytesIO(img_struct["bytes"]))
    
df = pl.from_arrow(ds.data.table)

# The image column is a struct with {"bytes": b"...", "path": "..."}
# Extract the raw bytes and open with PIL:
row = df.row(0, named=True)
img_bytes = row["image"]["bytes"]
image = Image.open(io.BytesIO(img_bytes))

# For batch processing:


images = [load_image(s) for s in df["image"].to_list()]

# %%
df
# Out:
# shape: (4_500, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ image     ┆ image_coc ┆ image_dat ┆ image_fil ┆ … ┆ image_lic ┆ image_ope ┆ annotatio ┆ annotati │
# │ ---       ┆ o_url     ┆ e_capture ┆ e_name    ┆   ┆ ense      ┆ n_images_ ┆ ns_ids    ┆ ons_capt │
# │ struct[2] ┆ ---       ┆ d         ┆ ---       ┆   ┆ ---       ┆ id        ┆ ---       ┆ ions     │
# │           ┆ str       ┆ ---       ┆ str       ┆   ┆ i8        ┆ ---       ┆ list[i32] ┆ ---      │
# │           ┆           ┆ str       ┆           ┆   ┆           ┆ str       ┆           ┆ list[str │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ]        │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ {b"\xff\x ┆ https://s ┆ 2018-11-0 ┆ 0013ea208 ┆ … ┆ 0         ┆ 0013ea208 ┆ [0, 1, …  ┆ ["A baby │
# ...
